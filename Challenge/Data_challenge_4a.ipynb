# %% [markdown]
# # Data Challenge 4

# %% [markdown]
# ## Introduction
#
# 4b: Matched filtering for (new) SNR with temlates of masses (m,m), where m goes from 10 to 50 M_sun
#
# 4c: Plotting the SNR timeseries for each signal identified from 4b
#
# 4d: Q-transfrom of each signal (H) and (L)
#
# 4e: Q-transfrom of glitches (H) and (L)
