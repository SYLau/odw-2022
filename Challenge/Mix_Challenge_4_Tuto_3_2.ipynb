# %% [markdown]
# <img style="float: left;padding: 1.3em" src="https://raw.githubusercontent.com/gw-odw/odw-2022/main/Tutorials/logo.png">
#
# #  Gravitational Wave Open Data Workshop #5
#
#
# #### Tutorial 3.2: Parameter estimation on GW150914 using open data.
#
# This example estimates the non-spinning parameters of the binary black hole system using
# commonly used prior distributions. This will take about 40 minutes to run.
#
# More examples at https://lscsoft.docs.ligo.org/bilby/examples.html
#
# [Click this link to view this tutorial in Google Colaboratory](https://colab.research.google.com/github/gw-odw/odw-2022/blob/main/Tutorials/Day_3/Tuto_3.2_Parameter_estimation_for_compact_object_mergers.ipynb)

# %% [markdown]
# ##  Installation  (execute only if running on a cloud platform!)

# %%
# -- Use the following line in Google Colab
! pip install -q lalsuite==6.82 bilby==1.0.4 gwpy==2.0.2 matplotlib==3.2.2 dynesty==1.0.0

# %% [markdown]
# **Important:** With Google Colab, you may need to restart the runtime after running the cell above.

# %% [markdown]
# ## Initialization
#
# We begin by importing some commonly used functions

# %%
# %matplotlib inline
from __future__ import division, print_function
import numpy as np
import matplotlib.pyplot as plt

import bilby
from bilby.core.prior import Uniform
from bilby.gw.conversion import convert_to_lal_binary_black_hole_parameters, generate_all_bbh_parameters

from gwpy.timeseries import TimeSeries

# -- download data
! wget https://www.gw-openscience.org/s/workshop3/challenge/challenge3.gwf
# Out:
# --2022-05-30 15:31:33--  https://www.gw-openscience.org/s/workshop3/challenge/challenge3.gwf
# Resolving www.gw-openscience.org (www.gw-openscience.org)... 131.215.113.73
# Connecting to www.gw-openscience.org (www.gw-openscience.org)|131.215.113.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256815066 (245M)
# Saving to: ‘challenge3.gwf.1’
#
# challenge3.gwf.1    100%[===================>] 244.92M  16.9MB/s    in 15s
#
# 2022-05-30 15:31:49 (16.6 MB/s) - ‘challenge3.gwf.1’ saved [256815066/256815066]

# %% [markdown]
# ## Bilby version

# %%
print(bilby.__version__)
# Out:
# 1.0.4: release

# %% [markdown]
# ## Getting the data: GW150914
#
# In this notebook, we'll analyse GW150914. Our first task is to obtain some data!
#
# We need to know the trigger time. This can be found on the [GWOSC page](https://www.gw-openscience.org/events/GW150914/), here we define it as a variable

# %%
time_of_event = 1126259462.4

# %% [markdown]
# ### Set up empty interferometers
#
# We need to get some data to analyse. We'll be using data from the Hanford (H1) and Livingston (L1) ground-based gravitational wave detectors. To organise ourselves, we'll create two "empty" interferometers. These are empty in the sense that they don't have any strain data. But, they know about the orientation and location of their respective namesakes. It may also be interesting to note that they are initialised with the planned design sensitivity power spectral density of advanced LIGO - we'll overwrite this later on, but it is often useful for simulations.

# %%
#H1 = bilby.gw.detector.get_empty_interferometer("H1")
#L1 = bilby.gw.detector.get_empty_interferometer("L1")

# %% [markdown]
# ### Download the data
#
# To analyse the signal, we need to download analysis data. Here, we will use [gwpy](https://gwpy.github.io/) to download the open strain data. For a general introduction to reading/writing data with gwpy, see [the documentation](https://gwpy.github.io/docs/stable/timeseries/).
#
# To analyse GW150914, we will use a 4s period duration centered on the event itself. It is standard to choose the data such that it always includes a "post trigger duration" of 2s. That is, there is always 2s of data after the trigger time. We therefore define all times relative to the trigger time, duration and this post-trigger duration.

# %%
# Use gwpy to fetch the open data
sampling_rate=4096 
duration=1*4
start_time=1203.8

psd_duration = duration * 32
psd_start_time = start_time - psd_duration

H1=bilby.gw.detector.get_empty_interferometer('H1')
H1.set_strain_data_from_frame_file('challenge3.gwf',sampling_rate, duration, start_time=start_time ,channel='H1:CHALLENGE3')
L1=bilby.gw.detector.get_empty_interferometer('L1')
L1.set_strain_data_from_frame_file('challenge3.gwf',sampling_rate, duration, start_time=start_time ,channel='L1:CHALLENGE3')
# Out:
# 15:31 bilby INFO    : Reading data from frame file challenge3.gwf
# 15:32 bilby INFO    : Successfully loaded H1:CHALLENGE3.
# 15:32 bilby INFO    : Reading data from frame file challenge3.gwf
# 15:32 bilby INFO    : Successfully loaded L1:CHALLENGE3.

# %% [markdown]
# ### Download the power spectral data
#
# Parameter estimation relies on having a power spectral density (PSD) - an estimate of the coloured noise properties of the data. Here, we will create a PSD using off-source data. For a review of methods to estimate PSDs, see, e.g. [Chatziioannou et al. (2019)](https://ui.adsabs.harvard.edu/abs/2019PhRvD.100j4004C/abstract).
#
# Again, we need to download this from the open strain data. We start by figuring out the amount of data needed - in this case 32 times the analysis duration. We fetch the segment with this duration immediately preceding the analysis segment.

# %%
psd_duration = duration * 32
psd_start_time = time_of_event - psd_duration

H1_psd_data = TimeSeries.fetch_open_data(
    "H1", psd_start_time, psd_start_time + psd_duration, sample_rate=4096, cache=True)

L1_psd_data = TimeSeries.fetch_open_data(
    "L1", psd_start_time, psd_start_time + psd_duration, sample_rate=4096, cache=True)

# %% [markdown]
# Having obtained the data to generate the PSD, we now use the standard [gwpy psd](https://gwpy.github.io/docs/stable/api/gwpy.timeseries.TimeSeries/#gwpy.timeseries.TimeSeries.psd) method to calculate the PSD. Here, the `psd_alpha` variable is converting the `roll_off` applied to the strain data into the fractional value used by `gwpy`. This applies a window with an appropriate shape to the time-domain data.

# %%
psd_alpha = 2 * H1.strain_data.roll_off / duration
H1_psd = H1_psd_data.psd(fftlength=duration, overlap=0, window=("tukey", psd_alpha), method="median")
L1_psd = L1_psd_data.psd(fftlength=duration, overlap=0, window=("tukey", psd_alpha), method="median")

# %% [markdown]
# ### Initialise the PSD
# Now that we have PSDs for H1 and L1, we can overwrite the `power_spectal_density` attribute of our interferometers with a new PSD.

# %%
H1.power_spectral_density = bilby.gw.detector.PowerSpectralDensity(
    frequency_array=H1_psd.frequencies.value, psd_array=H1_psd.value)
L1.power_spectral_density = bilby.gw.detector.PowerSpectralDensity(
    frequency_array=H1_psd.frequencies.value, psd_array=L1_psd.value)

# %% [markdown]
# ### Looking at the data
# Okay, we have spent a bit of time now downloading and initializing things. Let's check that everything makes sense. To do this, we'll plot our analysis data alongside the amplitude spectral density (ASD); this is just the square root of the PSD and has the right units to be comparable to the frequency-domain strain data.

# %%
fig, ax = plt.subplots()
idxs = H1.strain_data.frequency_mask  # This is a boolean mask of the frequencies which we'll use in the analysis
ax.loglog(H1.strain_data.frequency_array[idxs],
          np.abs(H1.strain_data.frequency_domain_strain[idxs]))
ax.loglog(H1.power_spectral_density.frequency_array[idxs],
          H1.power_spectral_density.asd_array[idxs])
ax.set_xlabel("Frequency [Hz]")
ax.set_ylabel("Strain [strain/$\sqrt{Hz}$]")
plt.show()
# Out:
# 15:32 bilby INFO    : Generating frequency domain strain from given time domain strain.
# 15:32 bilby INFO    : Applying a tukey window with alpha=0.1, roll off=0.2

# %% [markdown]
# What is happening at high frequencies? This is an artifact of the downsampling applied to the data - note that we downloaded the 4096Hz data which is downsampled from 16384Hz. We aren't really interested in the data at these high frequencies so let's adjust the maximum frequency used in the analysis to 1024 Hz and plot things again.

# %%
H1.maximum_frequency = 1024
L1.maximum_frequency = 1024

# %%
fig, ax = plt.subplots()
idxs = H1.strain_data.frequency_mask
ax.loglog(H1.strain_data.frequency_array[idxs],
          np.abs(H1.strain_data.frequency_domain_strain[idxs]))
ax.loglog(H1.power_spectral_density.frequency_array[idxs],
          H1.power_spectral_density.asd_array[idxs])
ax.set_xlabel("Frequency [Hz]")
ax.set_ylabel("Strain [strain/$\sqrt{Hz}$]")
plt.show()

# %% [markdown]
# Okay, that is better - we now won't analyse any data near to the artifact produced by downsampling. Now we have some sensible data to analyse so let's get right on with doing the analysis!

# %% [markdown]
# ## Low dimensional analysis
#
# In general a compact binary coalescence signal is described by 15 parameters describing the masses, spins, orientation, and position of the two compact objects along with a time at which the signal merges. The goal of parameter estimation is to figure out what the data (and any cogent prior information) can tell us about the likely values of these parameters - this is called the "posterior distribution of the parameters".
#
# To start with, we'll analyse the data fixing all but a few of the parameters to known values (in Bayesian lingo - we use delta function priors), this will enable us to run things in a few minutes rather than the many hours needed to do full parameter estimation.
#
# We'll start by thinking about the mass of the system. We call the heavier black hole the primary and label its mass $m_1$ and that of the secondary (lighter) black hole $m_2$. In this way, we always define $m_1 \ge m_2$. It turns out that inferences about $m_1$ and $m_2$ are highly correlated, we'll see exactly what this means later on.
#
# Bayesian inference methods are powerful at figuring out highly correlated posteriors. But, we can help it along by sampling in parameters which are not highly correlated. In particular, we define a new parameter called the [chirp mass](https://en.wikipedia.org/wiki/Chirp_mass) to be
#
# $$ \mathcal{M} = \frac{(m_1 m_2)^{3/5}}{(m_1 + m_2)^{1/5}} $$
#
# and the mass ratio
#
# $$ q = \frac{m_{2}}{m_1} $$
#
# If we sample (make inferences about) $\mathcal{M}$ and $q$, our code is much faster than if we use $m_1$ and $m_2$ directly! Note that so long as equivalent prior is given - one can also sample in the component masses themselves and you will get the same answer, it is just much slower!
#
# Once we have inferred $\mathcal{M}$ and $q$, we can then derive $m_1$ and $m_2$ from the resulting samples (we'll do that in just a moment).
#
# Okay, let's run a short (~1min on a single 2.8GHz core), low-dimensional parameter estimation analysis. This is done by defining a prior dictionary where all parameters are fixed, except those that we want to vary.

# %% [markdown]
# ### Create a prior
#
# Here, we create a prior fixing everything except the chirp mass, mass ratio, phase and geocent_time parameters to fixed values. The first two were described above. The second two give the phase of the system and the time at which it merges.

# %%
prior = bilby.core.prior.PriorDict()
prior['chirp_mass'] = Uniform(name='chirp_mass', minimum=30.0,maximum=32.5)
prior['mass_ratio'] = Uniform(name='mass_ratio', minimum=0.5, maximum=1)
prior['phase'] = Uniform(name="phase", minimum=0, maximum=2*np.pi)
prior['geocent_time'] = Uniform(name="geocent_time", minimum=start_time-0.1, maximum=start_time + duration +0.1)
prior['a_1'] =  0.0
prior['a_2'] =  0.0
prior['tilt_1'] =  0.0
prior['tilt_2'] =  0.0
prior['phi_12'] =  0.0
prior['phi_jl'] =  0.0
prior['dec'] =  -1.2232
prior['ra'] =  2.19432
prior['theta_jn'] =  1.89694
prior['psi'] =  0.532268
prior['luminosity_distance'] = 412.066

# %% [markdown]
# ## Create a likelihood
#
# For Bayesian inference, we need to evaluate the likelihood. In Bilby, we create a likelihood object. This is the communication interface between the sampling part of Bilby and the data. Explicitly, when Bilby is sampling it only uses the `parameters` and `log_likelihood()` of the likelihood object. This means the likelihood can be arbitrarily complicated and the sampling part of Bilby won't mind a bit!
#
# Let's create a `GravitationalWaveTransient`, a special inbuilt method carefully designed to wrap up evaluating the likelihood of a waveform model in some data.

# %%
# First, put our "data" created above into a list of interferometers (the order is arbitrary)
interferometers = [H1, L1]

# Next create a dictionary of arguments which we pass into the LALSimulation waveform - we specify the waveform approximant here
waveform_arguments = dict(
    waveform_approximant='IMRPhenomPv2', reference_frequency=100., catch_waveform_errors=True)

# Next, create a waveform_generator object. This wraps up some of the jobs of converting between parameters etc
waveform_generator = bilby.gw.WaveformGenerator(
    frequency_domain_source_model=bilby.gw.source.lal_binary_black_hole,
    waveform_arguments=waveform_arguments,
    parameter_conversion=convert_to_lal_binary_black_hole_parameters)

# Finally, create our likelihood, passing in what is needed to get going
likelihood = bilby.gw.likelihood.GravitationalWaveTransient(
    interferometers, waveform_generator, priors=prior,
    time_marginalization=True, phase_marginalization=True, distance_marginalization=False)
# Out:
# 15:36 bilby INFO    : Waveform generator initiated with
#   frequency_domain_source_model: bilby.gw.source.lal_binary_black_hole
#   time_domain_source_model: None
#   parameter_conversion: bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters

# %% [markdown]
# Note that we also specify `time_marginalization=True` and `phase_marginalization=True`. This is a trick often used in Bayesian inference. We analytically marginalize (integrate) over the time/phase of the system while sampling, effectively reducing the parameter space and making it easier to sample. Bilby will then figure out (after the sampling) posteriors for these marginalized parameters. For an introduction to this topic, see [Thrane & Talbot (2019)](https://arxiv.org/abs/1809.02293).

# %%
ifo_index = 0
idxs = interferometers[ifo_index].strain_data.frequency_mask
print(interferometers[ifo_index].strain_data.frequency_array[idxs])
print(np.abs(interferometers[ifo_index].strain_data.frequency_domain_strain[idxs]))
print(interferometers[ifo_index].power_spectral_density.frequency_array[idxs])
print(np.abs(interferometers[ifo_index].power_spectral_density.asd_array[idxs]))
print(len(interferometers[ifo_index].strain_data.frequency_domain_strain[idxs]))
# Out:
# [  20.     20.25   20.5  ... 1023.5  1023.75 1024.  ]
# [5.55535213e-22 3.82394363e-22 4.68678143e-22 ... 2.27890732e-24
#  2.16342611e-23 1.31518706e-23]
# [  20.     20.25   20.5  ... 1023.5  1023.75 1024.  ]
# [1.74486099e-22 1.27822074e-22 1.98055876e-22 ... 2.01481430e-23
#  2.17244237e-23 1.82386692e-23]
# 4017

# %% [markdown]
# ### Run the analysis

# %% [markdown]
# Now that the prior is set-up and the likelihood is set-up (with the data and the signal mode), we can run the sampler to get the posterior result. This function takes the likelihood and prior along with some options for how to do the sampling and how to save the data.

# %%
result_short = bilby.run_sampler(
    likelihood, prior, sampler='dynesty', outdir='short', label="GW150914",
    conversion_function=bilby.gw.conversion.generate_all_bbh_parameters,
    sample="unif", nlive=500, dlogz=3  # <- Arguments are used to make things fast - not recommended for general use
)
# Out:
# 15:36 bilby INFO    : Running for label 'GW150914', output will be saved to 'short'
# 15:36 bilby INFO    : Using lal version 7.1.2
# 15:36 bilby INFO    : Using lal git version Branch: None;Tag: lalsuite-v6.82;Id: cf792129c2473f42ce6c6ee21d8234254cefd337;;Builder: Unknown User <>;Repository status: UNCLEAN: Modified working tree
# 15:36 bilby INFO    : Using lalsimulation version 2.5.1
# 15:36 bilby INFO    : Using lalsimulation git version Branch: None;Tag: lalsuite-v6.82;Id: cf792129c2473f42ce6c6ee21d8234254cefd337;;Builder: Unknown User <>;Repository status: UNCLEAN: Modified working tree
# 15:36 bilby INFO    : Search parameters:
# 15:36 bilby INFO    :   chirp_mass = Uniform(minimum=30.0, maximum=32.5, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None)
# 15:36 bilby INFO    :   mass_ratio = Uniform(minimum=0.5, maximum=1, name='mass_ratio', latex_label='$q$', unit=None, boundary=None)
# 15:36 bilby INFO    :   time_jitter = Uniform(minimum=-0.000244140625, maximum=0.000244140625, name=None, latex_label=None, unit=None, boundary='periodic')
# 15:36 bilby INFO    :   phase = 0.0
# 15:36 bilby INFO    :   geocent_time = 1203.8000488280006
# 15:36 bilby INFO    :   a_1 = 0.0
# 15:36 bilby INFO    :   a_2 = 0.0
# 15:36 bilby INFO    :   tilt_1 = 0.0
# 15:36 bilby INFO    :   tilt_2 = 0.0
# 15:36 bilby INFO    :   phi_12 = 0.0
# 15:36 bilby INFO    :   phi_jl = 0.0
# 15:36 bilby INFO    :   dec = -1.2232
# 15:36 bilby INFO    :   ra = 2.19432
# 15:36 bilby INFO    :   theta_jn = 1.89694
# 15:36 bilby INFO    :   psi = 0.532268
# 15:36 bilby INFO    :   luminosity_distance = 412.066
# 15:36 bilby INFO    : Single likelihood evaluation took 1.607e-02 s
# 0it [00:00, ?it/s]
# 15:36 bilby INFO    : Using sampler Dynesty with kwargs {'bound': 'multi', 'sample': 'unif', 'verbose': True, 'periodic': None, 'reflective': None, 'check_point_delta_t': 600, 'nlive': 500, 'first_update': None, 'walks': 100, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'enlarge': 1.5, 'bootstrap': None, 'vol_dec': 0.5, 'vol_check': 8.0, 'facc': 0.2, 'slices': 5, 'update_interval': 300, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7f0424d3f8d0>>, 'dlogz': 3, 'maxiter': None, 'maxcall': None, 'logl_max': inf, 'add_live': True, 'print_progress': True, 'save_bounds': False, 'n_effective': None, 'maxmcmc': 5000, 'nact': 5}
# 15:36 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 15:36 bilby INFO    : Using dynesty version 1.0.0
# 15:36 bilby INFO    : Resume file short/GW150914_resume.pickle does not exist.
# 15:36 bilby INFO    : Generating initial points from the prior
# 1it [00:10, 10.65s/it, bound:0 nc:  1 ncall:5.0e+02 eff:0.2% logz-ratio=217.22+/-0.17 dlogz:inf>3]
# 7it [00:10,  1.13s/it, bound:0 nc:  1 ncall:5.1e+02 eff:1.4% logz-ratio=221.58+/-0.14 dlogz:34.503>3]
# 13it [00:10,  1.97it/s, bound:0 nc:  1 ncall:5.1e+02 eff:2.5% logz-ratio=223.52+/-0.13 dlogz:32.461>3]
# 19it [00:11,  3.45it/s, bound:0 nc:  1 ncall:5.2e+02 eff:3.7% logz-ratio=224.71+/-0.12 dlogz:31.189>3]
# 25it [00:11,  5.42it/s, bound:0 nc:  1 ncall:5.3e+02 eff:4.8% logz-ratio=225.99+/-0.12 dlogz:29.903>3]
# 31it [00:11,  7.98it/s, bound:0 nc:  1 ncall:5.3e+02 eff:5.8% logz-ratio=227.05+/-0.12 dlogz:28.844>3]
# 37it [00:11, 11.22it/s, bound:0 nc:  1 ncall:5.4e+02 eff:6.9% logz-ratio=228.20+/-0.12 dlogz:27.692>3]
# 43it [00:11, 15.06it/s, bound:0 nc:  1 ncall:5.4e+02 eff:7.9% logz-ratio=229.40+/-0.12 dlogz:26.491>3]
# 49it [00:11, 19.15it/s, bound:0 nc:  1 ncall:5.5e+02 eff:8.9% logz-ratio=230.38+/-0.12 dlogz:25.405>3]
# 55it [00:11, 23.43it/s, bound:0 nc:  1 ncall:5.6e+02 eff:9.9% logz-ratio=231.16+/-0.12 dlogz:24.609>3]
# 61it [00:11, 28.38it/s, bound:0 nc:  1 ncall:5.6e+02 eff:10.8% logz-ratio=231.79+/-0.11 dlogz:23.949>3]
# 67it [00:11, 32.13it/s, bound:0 nc:  1 ncall:5.7e+02 eff:11.7% logz-ratio=232.43+/-0.11 dlogz:23.295>3]
# 72it [00:12, 33.74it/s, bound:0 nc:  3 ncall:5.8e+02 eff:12.5% logz-ratio=232.93+/-0.11 dlogz:22.779>3]
# 77it [00:12, 35.73it/s, bound:0 nc:  1 ncall:5.8e+02 eff:13.2% logz-ratio=233.45+/-0.11 dlogz:22.265>3]
# 82it [00:12, 37.96it/s, bound:0 nc:  1 ncall:5.9e+02 eff:13.9% logz-ratio=233.95+/-0.11 dlogz:21.735>3]
# 87it [00:12, 39.51it/s, bound:0 nc:  1 ncall:6.0e+02 eff:14.6% logz-ratio=234.43+/-0.11 dlogz:21.237>3]
# 92it [00:12, 37.93it/s, bound:0 nc:  1 ncall:6.0e+02 eff:15.2% logz-ratio=234.92+/-0.11 dlogz:20.769>3]
# 97it [00:12, 39.27it/s, bound:0 nc:  1 ncall:6.1e+02 eff:15.9% logz-ratio=235.52+/-0.11 dlogz:20.158>3]
# 102it [00:12, 41.49it/s, bound:0 nc:  1 ncall:6.2e+02 eff:16.6% logz-ratio=236.01+/-0.11 dlogz:19.627>3]
# 107it [00:12, 42.70it/s, bound:0 nc:  1 ncall:6.2e+02 eff:17.2% logz-ratio=236.46+/-0.11 dlogz:19.169>3]
# 112it [00:13, 37.52it/s, bound:0 nc:  1 ncall:6.3e+02 eff:17.7% logz-ratio=236.87+/-0.11 dlogz:18.745>3]
# 117it [00:13, 39.36it/s, bound:0 nc:  1 ncall:6.4e+02 eff:18.3% logz-ratio=237.24+/-0.11 dlogz:18.352>3]
# 122it [00:13, 36.83it/s, bound:0 nc:  2 ncall:6.5e+02 eff:18.9% logz-ratio=237.62+/-0.11 dlogz:17.970>3]
# 128it [00:13, 40.26it/s, bound:0 nc:  2 ncall:6.5e+02 eff:19.6% logz-ratio=238.12+/-0.11 dlogz:17.461>3]
# 133it [00:13, 40.61it/s, bound:0 nc:  1 ncall:6.6e+02 eff:20.1% logz-ratio=238.51+/-0.11 dlogz:17.062>3]
# 138it [00:13, 36.09it/s, bound:0 nc:  1 ncall:6.7e+02 eff:20.6% logz-ratio=238.96+/-0.11 dlogz:16.608>3]
# 143it [00:13, 38.31it/s, bound:0 nc:  1 ncall:6.8e+02 eff:21.1% logz-ratio=239.34+/-0.11 dlogz:16.202>3]
# 149it [00:13, 42.47it/s, bound:0 nc:  1 ncall:6.8e+02 eff:21.8% logz-ratio=239.70+/-0.11 dlogz:15.809>3]
# 155it [00:14, 46.09it/s, bound:0 nc:  1 ncall:6.9e+02 eff:22.5% logz-ratio=240.01+/-0.11 dlogz:15.537>3]
# 160it [00:14, 40.74it/s, bound:0 nc:  1 ncall:7.0e+02 eff:22.9% logz-ratio=240.25+/-0.10 dlogz:15.283>3]
# 166it [00:14, 44.71it/s, bound:0 nc:  1 ncall:7.0e+02 eff:23.6% logz-ratio=240.50+/-0.10 dlogz:15.015>3]
# 171it [00:14, 43.49it/s, bound:0 nc:  1 ncall:7.1e+02 eff:24.1% logz-ratio=240.71+/-0.10 dlogz:14.801>3]
# 176it [00:14, 43.74it/s, bound:0 nc:  2 ncall:7.2e+02 eff:24.5% logz-ratio=240.94+/-0.10 dlogz:14.555>3]
# 181it [00:14, 42.11it/s, bound:0 nc:  1 ncall:7.2e+02 eff:25.0% logz-ratio=241.18+/-0.10 dlogz:14.309>3]
# 186it [00:14, 43.03it/s, bound:0 nc:  1 ncall:7.3e+02 eff:25.5% logz-ratio=241.42+/-0.10 dlogz:14.056>3]
# 191it [00:14, 43.98it/s, bound:0 nc:  1 ncall:7.4e+02 eff:26.0% logz-ratio=241.65+/-0.10 dlogz:13.818>3]
# 196it [00:15, 43.12it/s, bound:0 nc:  2 ncall:7.4e+02 eff:26.4% logz-ratio=241.88+/-0.10 dlogz:13.578>3]
# 201it [00:15, 40.91it/s, bound:0 nc:  3 ncall:7.5e+02 eff:26.8% logz-ratio=242.08+/-0.10 dlogz:13.365>3]
# 206it [00:15, 38.66it/s, bound:0 nc:  1 ncall:7.6e+02 eff:27.1% logz-ratio=242.26+/-0.10 dlogz:13.172>3]
# 211it [00:15, 40.13it/s, bound:0 nc:  1 ncall:7.6e+02 eff:27.6% logz-ratio=242.44+/-0.10 dlogz:12.979>3]
# 216it [00:15, 37.23it/s, bound:0 nc:  1 ncall:7.7e+02 eff:27.9% logz-ratio=242.60+/-0.10 dlogz:12.800>3]
# 220it [00:15, 37.34it/s, bound:0 nc:  3 ncall:7.8e+02 eff:28.2% logz-ratio=242.73+/-0.10 dlogz:12.665>3]
# 224it [00:15, 34.69it/s, bound:0 nc:  2 ncall:7.9e+02 eff:28.4% logz-ratio=242.85+/-0.10 dlogz:12.538>3]
# 228it [00:16, 30.70it/s, bound:0 nc:  3 ncall:8.0e+02 eff:28.6% logz-ratio=242.95+/-0.10 dlogz:12.421>3]
# 232it [00:16, 31.46it/s, bound:0 nc:  1 ncall:8.0e+02 eff:28.8% logz-ratio=243.06+/-0.10 dlogz:12.310>3]
# 236it [00:16, 30.89it/s, bound:0 nc:  4 ncall:8.1e+02 eff:29.1% logz-ratio=243.15+/-0.10 dlogz:12.205>3]
# 242it [00:16, 37.29it/s, bound:0 nc:  1 ncall:8.2e+02 eff:29.6% logz-ratio=243.30+/-0.09 dlogz:12.048>3]
# 247it [00:16, 38.24it/s, bound:0 nc:  2 ncall:8.2e+02 eff:29.9% logz-ratio=243.41+/-0.09 dlogz:11.921>3]
# 252it [00:16, 40.74it/s, bound:0 nc:  1 ncall:8.3e+02 eff:30.3% logz-ratio=243.52+/-0.09 dlogz:11.800>3]
# 258it [00:16, 42.41it/s, bound:0 nc:  2 ncall:8.4e+02 eff:30.8% logz-ratio=243.66+/-0.09 dlogz:11.656>3]
# 263it [00:16, 41.70it/s, bound:0 nc:  2 ncall:8.4e+02 eff:31.1% logz-ratio=243.76+/-0.09 dlogz:11.536>3]
# 268it [00:17, 36.37it/s, bound:0 nc:  1 ncall:8.6e+02 eff:31.3% logz-ratio=243.87+/-0.09 dlogz:11.422>3]
# 272it [00:17, 36.98it/s, bound:0 nc:  3 ncall:8.6e+02 eff:31.6% logz-ratio=243.95+/-0.09 dlogz:11.332>3]
# 276it [00:17, 32.68it/s, bound:0 nc:  2 ncall:8.7e+02 eff:31.7% logz-ratio=244.04+/-0.09 dlogz:11.234>3]
# 280it [00:17, 33.62it/s, bound:0 nc:  2 ncall:8.8e+02 eff:31.9% logz-ratio=244.13+/-0.09 dlogz:11.135>3]
# 284it [00:17, 31.61it/s, bound:0 nc:  2 ncall:8.8e+02 eff:32.1% logz-ratio=244.22+/-0.09 dlogz:11.040>3]
# 288it [00:17, 24.49it/s, bound:0 nc:  3 ncall:9.0e+02 eff:32.0% logz-ratio=244.30+/-0.09 dlogz:10.947>3]
# 292it [00:17, 27.21it/s, bound:0 nc:  1 ncall:9.1e+02 eff:32.2% logz-ratio=244.39+/-0.09 dlogz:10.853>3]
# 296it [00:18, 25.50it/s, bound:0 nc:  3 ncall:9.2e+02 eff:32.3% logz-ratio=244.48+/-0.09 dlogz:10.757>3]
# 300it [00:18, 28.16it/s, bound:0 nc:  1 ncall:9.2e+02 eff:32.5% logz-ratio=244.56+/-0.09 dlogz:10.664>3]
# 304it [00:18, 28.13it/s, bound:0 nc:  1 ncall:9.3e+02 eff:32.7% logz-ratio=244.64+/-0.09 dlogz:10.572>3]
# 309it [00:18, 30.95it/s, bound:0 nc:  2 ncall:9.4e+02 eff:32.9% logz-ratio=244.75+/-0.09 dlogz:10.461>3]
# 314it [00:18, 35.04it/s, bound:0 nc:  1 ncall:9.4e+02 eff:33.3% logz-ratio=244.85+/-0.09 dlogz:10.348>3]
# 318it [00:18, 33.19it/s, bound:0 nc:  3 ncall:9.5e+02 eff:33.4% logz-ratio=244.93+/-0.09 dlogz:10.259>3]
# 323it [00:18, 34.01it/s, bound:0 nc:  3 ncall:9.6e+02 eff:33.6% logz-ratio=245.03+/-0.09 dlogz:10.147>3]
# 328it [00:18, 36.77it/s, bound:0 nc:  2 ncall:9.7e+02 eff:34.0% logz-ratio=245.13+/-0.09 dlogz:10.037>3]
# 332it [00:19, 30.87it/s, bound:0 nc:  2 ncall:9.8e+02 eff:34.0% logz-ratio=245.21+/-0.09 dlogz:9.947>3]
# 336it [00:19, 32.42it/s, bound:0 nc:  2 ncall:9.8e+02 eff:34.2% logz-ratio=245.30+/-0.09 dlogz:9.858>3]
# 340it [00:19, 32.84it/s, bound:0 nc:  1 ncall:9.9e+02 eff:34.4% logz-ratio=245.38+/-0.09 dlogz:9.768>3]
# 344it [00:19, 32.26it/s, bound:0 nc:  1 ncall:1.0e+03 eff:34.5% logz-ratio=245.46+/-0.09 dlogz:9.679>3]
# 348it [00:19, 27.92it/s, bound:0 nc:  2 ncall:1.0e+03 eff:34.6% logz-ratio=245.54+/-0.09 dlogz:9.592>3]
# 352it [00:19, 29.15it/s, bound:0 nc:  3 ncall:1.0e+03 eff:34.7% logz-ratio=245.61+/-0.09 dlogz:9.506>3]
# 356it [00:19, 28.22it/s, bound:0 nc:  4 ncall:1.0e+03 eff:34.8% logz-ratio=245.69+/-0.09 dlogz:9.420>3]
# 361it [00:20, 32.89it/s, bound:0 nc:  1 ncall:1.0e+03 eff:35.1% logz-ratio=245.79+/-0.09 dlogz:9.309>3]
# 365it [00:20, 31.74it/s, bound:0 nc:  3 ncall:1.0e+03 eff:35.2% logz-ratio=245.87+/-0.09 dlogz:9.223>3]
# 369it [00:20, 31.83it/s, bound:0 nc:  1 ncall:1.0e+03 eff:35.3% logz-ratio=245.95+/-0.09 dlogz:9.140>3]
# 373it [00:20, 28.86it/s, bound:0 nc:  2 ncall:1.1e+03 eff:35.4% logz-ratio=246.02+/-0.09 dlogz:9.057>3]
# 377it [00:20, 23.29it/s, bound:0 nc:  1 ncall:1.1e+03 eff:35.3% logz-ratio=246.10+/-0.09 dlogz:8.974>3]
# 381it [00:20, 25.37it/s, bound:0 nc:  3 ncall:1.1e+03 eff:35.4% logz-ratio=246.17+/-0.09 dlogz:8.893>3]
# 384it [00:21, 23.56it/s, bound:0 nc:  2 ncall:1.1e+03 eff:35.4% logz-ratio=246.22+/-0.09 dlogz:8.833>3]
# 388it [00:21, 26.84it/s, bound:0 nc:  1 ncall:1.1e+03 eff:35.6% logz-ratio=246.30+/-0.09 dlogz:8.752>3]
# 392it [00:21, 29.12it/s, bound:0 nc:  1 ncall:1.1e+03 eff:35.8% logz-ratio=246.37+/-0.09 dlogz:8.669>3]
# 396it [00:21, 29.42it/s, bound:0 nc:  2 ncall:1.1e+03 eff:35.9% logz-ratio=246.44+/-0.09 dlogz:8.587>3]
# 400it [00:21, 28.83it/s, bound:0 nc:  2 ncall:1.1e+03 eff:36.0% logz-ratio=246.52+/-0.09 dlogz:8.506>3]
# 403it [00:21, 26.56it/s, bound:0 nc:  1 ncall:1.1e+03 eff:36.0% logz-ratio=246.57+/-0.09 dlogz:8.448>3]
# 406it [00:21, 26.85it/s, bound:0 nc:  2 ncall:1.1e+03 eff:36.1% logz-ratio=246.62+/-0.09 dlogz:8.389>3]
# 409it [00:21, 25.64it/s, bound:0 nc:  2 ncall:1.1e+03 eff:36.1% logz-ratio=246.67+/-0.09 dlogz:8.332>3]
# 413it [00:22, 28.36it/s, bound:0 nc:  1 ncall:1.1e+03 eff:36.3% logz-ratio=246.74+/-0.09 dlogz:8.257>3]
# 417it [00:22, 24.58it/s, bound:0 nc:  8 ncall:1.2e+03 eff:36.3% logz-ratio=246.80+/-0.09 dlogz:8.184>3]
# 422it [00:22, 29.26it/s, bound:0 nc:  1 ncall:1.2e+03 eff:36.5% logz-ratio=246.89+/-0.09 dlogz:8.092>3]
# 426it [00:22, 27.13it/s, bound:0 nc:  1 ncall:1.2e+03 eff:36.6% logz-ratio=246.95+/-0.09 dlogz:8.018>3]
# 430it [00:22, 29.12it/s, bound:0 nc:  1 ncall:1.2e+03 eff:36.7% logz-ratio=247.02+/-0.09 dlogz:7.943>3]
# 434it [00:22, 30.01it/s, bound:0 nc:  2 ncall:1.2e+03 eff:36.8% logz-ratio=247.09+/-0.09 dlogz:7.867>3]
# 438it [00:22, 30.42it/s, bound:0 nc:  1 ncall:1.2e+03 eff:37.0% logz-ratio=247.16+/-0.09 dlogz:7.790>3]
# 442it [00:23, 20.22it/s, bound:0 nc:  1 ncall:1.2e+03 eff:36.6% logz-ratio=247.23+/-0.09 dlogz:7.712>3]
# 447it [00:23, 23.94it/s, bound:0 nc:  3 ncall:1.2e+03 eff:36.8% logz-ratio=247.31+/-0.09 dlogz:7.617>3]
# 451it [00:23, 23.73it/s, bound:0 nc:  5 ncall:1.2e+03 eff:36.8% logz-ratio=247.37+/-0.09 dlogz:7.545>3]
# 454it [00:23, 21.71it/s, bound:0 nc:  6 ncall:1.2e+03 eff:36.8% logz-ratio=247.42+/-0.09 dlogz:7.492>3]
# 457it [00:23, 19.41it/s, bound:0 nc:  1 ncall:1.2e+03 eff:36.6% logz-ratio=247.47+/-0.09 dlogz:7.440>3]
# 460it [00:24, 17.52it/s, bound:0 nc:  3 ncall:1.3e+03 eff:36.5% logz-ratio=247.51+/-0.09 dlogz:7.388>3]
# 465it [00:24, 21.84it/s, bound:0 nc:  4 ncall:1.3e+03 eff:36.7% logz-ratio=247.59+/-0.09 dlogz:7.303>3]
# 468it [00:24, 22.98it/s, bound:0 nc:  3 ncall:1.3e+03 eff:36.7% logz-ratio=247.63+/-0.09 dlogz:7.252>3]
# 471it [00:24, 22.03it/s, bound:0 nc:  2 ncall:1.3e+03 eff:36.7% logz-ratio=247.68+/-0.09 dlogz:7.200>3]
# 474it [00:24, 20.74it/s, bound:0 nc:  1 ncall:1.3e+03 eff:36.7% logz-ratio=247.72+/-0.09 dlogz:7.149>3]
# 477it [00:24, 20.21it/s, bound:0 nc:  1 ncall:1.3e+03 eff:36.7% logz-ratio=247.77+/-0.09 dlogz:7.099>3]
# 480it [00:25, 20.46it/s, bound:0 nc:  4 ncall:1.3e+03 eff:36.7% logz-ratio=247.81+/-0.09 dlogz:7.048>3]
# 483it [00:25, 21.99it/s, bound:0 nc:  1 ncall:1.3e+03 eff:36.8% logz-ratio=247.86+/-0.09 dlogz:6.998>3]
# 486it [00:25, 23.21it/s, bound:0 nc:  2 ncall:1.3e+03 eff:36.8% logz-ratio=247.90+/-0.09 dlogz:6.946>3]
# 489it [00:25, 21.81it/s, bound:0 nc:  7 ncall:1.3e+03 eff:36.8% logz-ratio=247.95+/-0.09 dlogz:6.894>3]
# 492it [00:25, 19.78it/s, bound:0 nc:  1 ncall:1.3e+03 eff:36.7% logz-ratio=248.00+/-0.09 dlogz:6.842>3]
# 496it [00:25, 23.83it/s, bound:0 nc:  3 ncall:1.3e+03 eff:36.9% logz-ratio=248.06+/-0.09 dlogz:6.773>3]
# 499it [00:25, 23.21it/s, bound:0 nc:  2 ncall:1.4e+03 eff:36.9% logz-ratio=248.10+/-0.09 dlogz:6.721>3]
# 502it [00:25, 23.64it/s, bound:0 nc:  1 ncall:1.4e+03 eff:36.9% logz-ratio=248.15+/-0.09 dlogz:6.667>3]
# 505it [00:26, 24.91it/s, bound:0 nc:  2 ncall:1.4e+03 eff:37.0% logz-ratio=248.20+/-0.09 dlogz:6.614>3]
# 508it [00:26, 25.13it/s, bound:0 nc:  3 ncall:1.4e+03 eff:37.0% logz-ratio=248.24+/-0.09 dlogz:6.563>3]
# 511it [00:26, 22.61it/s, bound:0 nc:  4 ncall:1.4e+03 eff:36.9% logz-ratio=248.29+/-0.09 dlogz:6.511>3]
# 514it [00:26, 23.12it/s, bound:0 nc:  3 ncall:1.4e+03 eff:37.0% logz-ratio=248.33+/-0.09 dlogz:6.461>3]
# 517it [00:26, 23.81it/s, bound:0 nc:  4 ncall:1.4e+03 eff:37.0% logz-ratio=248.37+/-0.09 dlogz:6.413>3]
# 520it [00:26, 22.50it/s, bound:0 nc:  1 ncall:1.4e+03 eff:37.0% logz-ratio=248.42+/-0.09 dlogz:6.365>3]
# 523it [00:26, 22.27it/s, bound:0 nc:  1 ncall:1.4e+03 eff:37.0% logz-ratio=248.46+/-0.09 dlogz:6.318>3]
# 526it [00:27, 16.51it/s, bound:0 nc: 10 ncall:1.4e+03 eff:36.8% logz-ratio=248.50+/-0.09 dlogz:6.272>3]
# 528it [00:27, 13.20it/s, bound:0 nc: 10 ncall:1.4e+03 eff:36.5% logz-ratio=248.52+/-0.09 dlogz:6.241>3]
# 531it [00:27, 15.33it/s, bound:0 nc:  3 ncall:1.5e+03 eff:36.5% logz-ratio=248.56+/-0.09 dlogz:6.195>3]
# 533it [00:27, 16.12it/s, bound:0 nc:  2 ncall:1.5e+03 eff:36.5% logz-ratio=248.59+/-0.09 dlogz:6.165>3]
# 536it [00:27, 17.44it/s, bound:0 nc:  3 ncall:1.5e+03 eff:36.5% logz-ratio=248.63+/-0.09 dlogz:6.121>3]
# 538it [00:27, 17.09it/s, bound:0 nc:  4 ncall:1.5e+03 eff:36.5% logz-ratio=248.65+/-0.09 dlogz:6.092>3]
# 540it [00:28, 15.95it/s, bound:0 nc:  4 ncall:1.5e+03 eff:36.4% logz-ratio=248.68+/-0.09 dlogz:6.063>3]
# 542it [00:28, 15.31it/s, bound:0 nc:  1 ncall:1.5e+03 eff:36.4% logz-ratio=248.70+/-0.09 dlogz:6.034>3]
# 544it [00:28, 15.57it/s, bound:0 nc:  6 ncall:1.5e+03 eff:36.3% logz-ratio=248.73+/-0.09 dlogz:6.006>3]
# 546it [00:28, 14.17it/s, bound:0 nc:  8 ncall:1.5e+03 eff:36.2% logz-ratio=248.75+/-0.09 dlogz:5.978>3]
# 548it [00:28, 15.37it/s, bound:0 nc:  2 ncall:1.5e+03 eff:36.2% logz-ratio=248.77+/-0.09 dlogz:5.949>3]
# 550it [00:28, 14.84it/s, bound:0 nc:  6 ncall:1.5e+03 eff:36.2% logz-ratio=248.80+/-0.09 dlogz:5.921>3]
# 555it [00:28, 20.42it/s, bound:0 nc:  4 ncall:1.5e+03 eff:36.3% logz-ratio=248.86+/-0.09 dlogz:5.851>3]
# 558it [00:29, 19.58it/s, bound:0 nc:  3 ncall:1.5e+03 eff:36.3% logz-ratio=248.89+/-0.09 dlogz:5.811>3]
# 561it [00:29, 19.67it/s, bound:0 nc:  4 ncall:1.5e+03 eff:36.2% logz-ratio=248.93+/-0.09 dlogz:5.771>3]
# 564it [00:29, 20.87it/s, bound:0 nc:  3 ncall:1.6e+03 eff:36.3% logz-ratio=248.96+/-0.09 dlogz:5.732>3]
# 567it [00:29, 16.50it/s, bound:0 nc:  5 ncall:1.6e+03 eff:36.1% logz-ratio=248.99+/-0.09 dlogz:5.693>3]
# 569it [00:29, 15.47it/s, bound:0 nc:  2 ncall:1.6e+03 eff:36.0% logz-ratio=249.01+/-0.09 dlogz:5.668>3]
# 574it [00:29, 21.97it/s, bound:0 nc:  1 ncall:1.6e+03 eff:36.2% logz-ratio=249.07+/-0.09 dlogz:5.604>3]
# 577it [00:30, 18.28it/s, bound:0 nc:  1 ncall:1.6e+03 eff:36.1% logz-ratio=249.10+/-0.09 dlogz:5.566>3]
# 580it [00:30, 14.72it/s, bound:0 nc:  6 ncall:1.6e+03 eff:35.8% logz-ratio=249.13+/-0.09 dlogz:5.529>3]
# 582it [00:30, 15.01it/s, bound:0 nc:  3 ncall:1.6e+03 eff:35.8% logz-ratio=249.15+/-0.09 dlogz:5.504>3]
# 584it [00:30, 14.81it/s, bound:0 nc:  6 ncall:1.6e+03 eff:35.8% logz-ratio=249.17+/-0.09 dlogz:5.479>3]
# 587it [00:30, 17.36it/s, bound:0 nc:  1 ncall:1.6e+03 eff:35.8% logz-ratio=249.20+/-0.09 dlogz:5.442>3]
# 589it [00:30, 17.66it/s, bound:0 nc:  1 ncall:1.6e+03 eff:35.8% logz-ratio=249.22+/-0.09 dlogz:5.418>3]
# 593it [00:31, 22.67it/s, bound:0 nc:  1 ncall:1.7e+03 eff:35.9% logz-ratio=249.26+/-0.09 dlogz:5.369>3]
# 596it [00:31, 20.41it/s, bound:0 nc:  6 ncall:1.7e+03 eff:35.9% logz-ratio=249.29+/-0.09 dlogz:5.334>3]
# 599it [00:31, 20.32it/s, bound:0 nc:  4 ncall:1.7e+03 eff:35.8% logz-ratio=249.32+/-0.09 dlogz:5.299>3]
# 602it [00:31, 18.80it/s, bound:0 nc:  4 ncall:1.7e+03 eff:35.8% logz-ratio=249.35+/-0.09 dlogz:5.264>3]
# 605it [00:31, 19.83it/s, bound:0 nc:  1 ncall:1.7e+03 eff:35.8% logz-ratio=249.38+/-0.09 dlogz:5.230>3]
# 609it [00:31, 20.86it/s, bound:0 nc:  5 ncall:1.7e+03 eff:35.8% logz-ratio=249.42+/-0.09 dlogz:5.184>3]
# 612it [00:32, 20.59it/s, bound:0 nc:  2 ncall:1.7e+03 eff:35.8% logz-ratio=249.45+/-0.09 dlogz:5.151>3]
# 615it [00:32, 21.60it/s, bound:0 nc:  4 ncall:1.7e+03 eff:35.9% logz-ratio=249.47+/-0.09 dlogz:5.117>3]
# 618it [00:32, 21.02it/s, bound:0 nc:  2 ncall:1.7e+03 eff:35.8% logz-ratio=249.50+/-0.09 dlogz:5.084>3]
# 621it [00:32, 20.63it/s, bound:0 nc:  4 ncall:1.7e+03 eff:35.8% logz-ratio=249.53+/-0.09 dlogz:5.051>3]
# 624it [00:32, 16.33it/s, bound:0 nc: 10 ncall:1.7e+03 eff:35.7% logz-ratio=249.55+/-0.09 dlogz:5.018>3]
# 626it [00:32, 16.37it/s, bound:0 nc:  5 ncall:1.8e+03 eff:35.6% logz-ratio=249.57+/-0.09 dlogz:4.997>3]
# 628it [00:32, 16.45it/s, bound:0 nc:  1 ncall:1.8e+03 eff:35.6% logz-ratio=249.59+/-0.09 dlogz:4.975>3]
# 631it [00:33, 18.51it/s, bound:0 nc:  2 ncall:1.8e+03 eff:35.6% logz-ratio=249.62+/-0.09 dlogz:4.943>3]
# 633it [00:33, 18.64it/s, bound:0 nc:  3 ncall:1.8e+03 eff:35.6% logz-ratio=249.63+/-0.09 dlogz:4.921>3]
# 635it [00:33, 18.08it/s, bound:0 nc:  5 ncall:1.8e+03 eff:35.6% logz-ratio=249.65+/-0.09 dlogz:4.900>3]
# 638it [00:33, 19.12it/s, bound:0 nc:  3 ncall:1.8e+03 eff:35.6% logz-ratio=249.68+/-0.09 dlogz:4.868>3]
# 640it [00:33, 16.57it/s, bound:0 nc:  9 ncall:1.8e+03 eff:35.5% logz-ratio=249.69+/-0.09 dlogz:4.847>3]
# 642it [00:33, 12.82it/s, bound:0 nc:  8 ncall:1.8e+03 eff:35.4% logz-ratio=249.71+/-0.09 dlogz:4.826>3]
# 644it [00:33, 13.63it/s, bound:0 nc:  1 ncall:1.8e+03 eff:35.3% logz-ratio=249.73+/-0.09 dlogz:4.805>3]
# 646it [00:34, 10.36it/s, bound:0 nc:  6 ncall:1.8e+03 eff:35.1% logz-ratio=249.75+/-0.09 dlogz:4.783>3]
# 648it [00:34, 11.95it/s, bound:0 nc:  3 ncall:1.8e+03 eff:35.1% logz-ratio=249.77+/-0.09 dlogz:4.761>3]
# 653it [00:34, 18.67it/s, bound:0 nc:  2 ncall:1.9e+03 eff:35.2% logz-ratio=249.81+/-0.09 dlogz:4.708>3]
# 656it [00:34, 17.62it/s, bound:0 nc:  2 ncall:1.9e+03 eff:35.2% logz-ratio=249.84+/-0.09 dlogz:4.676>3]
# 659it [00:34, 15.82it/s, bound:0 nc:  1 ncall:1.9e+03 eff:35.1% logz-ratio=249.86+/-0.09 dlogz:4.645>3]
# 662it [00:35, 17.17it/s, bound:0 nc:  4 ncall:1.9e+03 eff:35.1% logz-ratio=249.89+/-0.09 dlogz:4.614>3]
# 664it [00:35, 17.72it/s, bound:0 nc:  3 ncall:1.9e+03 eff:35.1% logz-ratio=249.90+/-0.09 dlogz:4.593>3]
# 666it [00:35, 17.79it/s, bound:0 nc:  4 ncall:1.9e+03 eff:35.1% logz-ratio=249.92+/-0.09 dlogz:4.573>3]
# 669it [00:35, 17.30it/s, bound:0 nc:  7 ncall:1.9e+03 eff:35.0% logz-ratio=249.94+/-0.09 dlogz:4.543>3]
# 671it [00:35, 16.79it/s, bound:0 nc:  2 ncall:1.9e+03 eff:35.0% logz-ratio=249.96+/-0.09 dlogz:4.522>3]
# 673it [00:35, 13.55it/s, bound:0 nc:  4 ncall:1.9e+03 eff:34.9% logz-ratio=249.98+/-0.09 dlogz:4.502>3]
# 676it [00:35, 16.59it/s, bound:0 nc:  3 ncall:1.9e+03 eff:34.9% logz-ratio=250.00+/-0.09 dlogz:4.471>3]
# 678it [00:36, 16.93it/s, bound:0 nc:  3 ncall:1.9e+03 eff:34.9% logz-ratio=250.02+/-0.09 dlogz:4.451>3]
# 680it [00:36, 16.89it/s, bound:0 nc:  2 ncall:1.9e+03 eff:34.9% logz-ratio=250.04+/-0.09 dlogz:4.431>3]
# 684it [00:36, 19.79it/s, bound:0 nc:  5 ncall:2.0e+03 eff:35.0% logz-ratio=250.07+/-0.09 dlogz:4.390>3]
# 687it [00:36, 19.78it/s, bound:0 nc:  4 ncall:2.0e+03 eff:35.0% logz-ratio=250.09+/-0.09 dlogz:4.360>3]
# 690it [00:36, 15.30it/s, bound:0 nc:  9 ncall:2.0e+03 eff:34.8% logz-ratio=250.12+/-0.09 dlogz:4.329>3]
# 693it [00:36, 16.82it/s, bound:0 nc:  4 ncall:2.0e+03 eff:34.8% logz-ratio=250.14+/-0.09 dlogz:4.299>3]
# 695it [00:37, 17.17it/s, bound:0 nc:  3 ncall:2.0e+03 eff:34.8% logz-ratio=250.16+/-0.09 dlogz:4.278>3]
# 697it [00:37, 16.33it/s, bound:0 nc:  6 ncall:2.0e+03 eff:34.8% logz-ratio=250.18+/-0.09 dlogz:4.258>3]
# 699it [00:37, 13.89it/s, bound:0 nc: 10 ncall:2.0e+03 eff:34.7% logz-ratio=250.19+/-0.09 dlogz:4.237>3]
# 702it [00:37, 15.45it/s, bound:0 nc:  7 ncall:2.0e+03 eff:34.7% logz-ratio=250.22+/-0.09 dlogz:4.208>3]
# 704it [00:37, 15.86it/s, bound:0 nc:  2 ncall:2.0e+03 eff:34.7% logz-ratio=250.23+/-0.09 dlogz:4.188>3]
# 706it [00:37, 12.89it/s, bound:0 nc: 12 ncall:2.0e+03 eff:34.5% logz-ratio=250.25+/-0.09 dlogz:4.168>3]
# 708it [00:38,  9.01it/s, bound:0 nc: 10 ncall:2.1e+03 eff:34.2% logz-ratio=250.26+/-0.09 dlogz:4.149>3]
# 711it [00:38, 11.77it/s, bound:0 nc:  4 ncall:2.1e+03 eff:34.2% logz-ratio=250.29+/-0.09 dlogz:4.119>3]
# 714it [00:38, 13.80it/s, bound:0 nc:  3 ncall:2.1e+03 eff:34.3% logz-ratio=250.31+/-0.09 dlogz:4.090>3]
# 717it [00:38, 15.93it/s, bound:0 nc:  2 ncall:2.1e+03 eff:34.3% logz-ratio=250.34+/-0.09 dlogz:4.060>3]
# 719it [00:38, 15.37it/s, bound:0 nc:  4 ncall:2.1e+03 eff:34.3% logz-ratio=250.35+/-0.09 dlogz:4.041>3]
# 723it [00:38, 19.56it/s, bound:0 nc:  3 ncall:2.1e+03 eff:34.3% logz-ratio=250.38+/-0.09 dlogz:4.002>3]
# 726it [00:39, 17.01it/s, bound:0 nc:  8 ncall:2.1e+03 eff:34.2% logz-ratio=250.41+/-0.09 dlogz:3.973>3]
# 729it [00:39, 19.41it/s, bound:0 nc:  3 ncall:2.1e+03 eff:34.3% logz-ratio=250.43+/-0.09 dlogz:3.945>3]
# 732it [00:39, 15.22it/s, bound:0 nc:  2 ncall:2.1e+03 eff:34.1% logz-ratio=250.45+/-0.09 dlogz:3.917>3]
# 735it [00:39, 17.79it/s, bound:0 nc:  1 ncall:2.2e+03 eff:34.2% logz-ratio=250.47+/-0.09 dlogz:3.889>3]
# 738it [00:39, 18.07it/s, bound:0 nc:  3 ncall:2.2e+03 eff:34.2% logz-ratio=250.50+/-0.09 dlogz:3.877>3]
# 741it [00:39, 18.54it/s, bound:0 nc:  6 ncall:2.2e+03 eff:34.2% logz-ratio=250.52+/-0.09 dlogz:3.849>3]
# 744it [00:40, 15.05it/s, bound:0 nc:  7 ncall:2.2e+03 eff:34.0% logz-ratio=250.54+/-0.09 dlogz:3.822>3]
# 746it [00:40, 12.98it/s, bound:0 nc: 13 ncall:2.2e+03 eff:33.9% logz-ratio=250.56+/-0.09 dlogz:3.803>3]
# 748it [00:40, 13.69it/s, bound:0 nc:  6 ncall:2.2e+03 eff:33.9% logz-ratio=250.57+/-0.09 dlogz:3.785>3]
# 750it [00:40, 12.32it/s, bound:0 nc:  7 ncall:2.2e+03 eff:33.8% logz-ratio=250.59+/-0.09 dlogz:3.767>3]
# 753it [00:41, 12.91it/s, bound:0 nc:  9 ncall:2.2e+03 eff:33.8% logz-ratio=250.61+/-0.09 dlogz:3.740>3]
# 755it [00:41, 10.80it/s, bound:0 nc: 11 ncall:2.2e+03 eff:33.6% logz-ratio=250.62+/-0.09 dlogz:3.722>3]
# 757it [00:41,  9.88it/s, bound:0 nc:  3 ncall:2.3e+03 eff:33.5% logz-ratio=250.64+/-0.09 dlogz:3.704>3]
# 759it [00:41, 11.33it/s, bound:0 nc:  5 ncall:2.3e+03 eff:33.5% logz-ratio=250.65+/-0.09 dlogz:3.686>3]
# 761it [00:41, 12.03it/s, bound:0 nc:  1 ncall:2.3e+03 eff:33.4% logz-ratio=250.66+/-0.09 dlogz:3.668>3]
# 764it [00:41, 13.55it/s, bound:0 nc:  6 ncall:2.3e+03 eff:33.4% logz-ratio=250.69+/-0.09 dlogz:3.641>3]
# 767it [00:42, 13.02it/s, bound:0 nc: 11 ncall:2.3e+03 eff:33.3% logz-ratio=250.71+/-0.09 dlogz:3.615>3]
# 770it [00:42, 12.68it/s, bound:0 nc: 12 ncall:2.3e+03 eff:33.2% logz-ratio=250.73+/-0.09 dlogz:3.588>3]
# 772it [00:42, 13.70it/s, bound:0 nc:  2 ncall:2.3e+03 eff:33.2% logz-ratio=250.74+/-0.09 dlogz:3.571>3]
# 774it [00:42, 13.87it/s, bound:0 nc:  7 ncall:2.3e+03 eff:33.2% logz-ratio=250.76+/-0.09 dlogz:3.554>3]
# 776it [00:43, 10.28it/s, bound:0 nc: 15 ncall:2.4e+03 eff:33.0% logz-ratio=250.77+/-0.09 dlogz:3.537>3]
# 778it [00:43, 11.48it/s, bound:0 nc:  3 ncall:2.4e+03 eff:33.0% logz-ratio=250.78+/-0.09 dlogz:3.520>3]
# 780it [00:43, 12.96it/s, bound:0 nc:  1 ncall:2.4e+03 eff:33.0% logz-ratio=250.80+/-0.09 dlogz:3.503>3]
# 784it [00:43, 16.86it/s, bound:0 nc:  4 ncall:2.4e+03 eff:33.1% logz-ratio=250.82+/-0.09 dlogz:3.469>3]
# 786it [00:43, 13.12it/s, bound:0 nc:  5 ncall:2.4e+03 eff:32.9% logz-ratio=250.84+/-0.09 dlogz:3.453>3]
# 788it [00:43, 13.42it/s, bound:0 nc:  2 ncall:2.4e+03 eff:32.9% logz-ratio=250.85+/-0.09 dlogz:3.436>3]
# 791it [00:43, 15.79it/s, bound:0 nc:  2 ncall:2.4e+03 eff:32.9% logz-ratio=250.87+/-0.08 dlogz:3.412>3]
# 794it [00:44, 16.30it/s, bound:0 nc:  6 ncall:2.4e+03 eff:32.9% logz-ratio=250.89+/-0.08 dlogz:3.387>3]
# 796it [00:44, 16.78it/s, bound:0 nc:  4 ncall:2.4e+03 eff:32.9% logz-ratio=250.90+/-0.08 dlogz:3.371>3]
# 799it [00:44, 17.07it/s, bound:0 nc:  5 ncall:2.4e+03 eff:32.9% logz-ratio=250.92+/-0.08 dlogz:3.348>3]
# 801it [00:44, 13.61it/s, bound:0 nc:  5 ncall:2.4e+03 eff:32.8% logz-ratio=250.93+/-0.08 dlogz:3.332>3]
# 803it [00:44, 11.58it/s, bound:0 nc:  9 ncall:2.5e+03 eff:32.7% logz-ratio=250.94+/-0.08 dlogz:3.317>3]
# 806it [00:45, 13.12it/s, bound:0 nc:  5 ncall:2.5e+03 eff:32.7% logz-ratio=250.96+/-0.08 dlogz:3.293>3]
# 808it [00:45,  8.18it/s, bound:0 nc: 18 ncall:2.5e+03 eff:32.3% logz-ratio=250.97+/-0.08 dlogz:3.278>3]
# 811it [00:45, 10.96it/s, bound:0 nc:  2 ncall:2.5e+03 eff:32.4% logz-ratio=250.99+/-0.08 dlogz:3.255>3]
# 813it [00:45, 11.45it/s, bound:0 nc:  8 ncall:2.5e+03 eff:32.4% logz-ratio=251.00+/-0.08 dlogz:3.240>3]
# 815it [00:45, 12.19it/s, bound:0 nc:  3 ncall:2.5e+03 eff:32.4% logz-ratio=251.01+/-0.08 dlogz:3.225>3]
# 817it [00:46,  9.52it/s, bound:0 nc:  5 ncall:2.5e+03 eff:32.2% logz-ratio=251.03+/-0.08 dlogz:3.210>3]
# 819it [00:46,  8.86it/s, bound:0 nc: 13 ncall:2.6e+03 eff:32.1% logz-ratio=251.04+/-0.08 dlogz:3.195>3]
# 822it [00:46, 10.13it/s, bound:0 nc: 10 ncall:2.6e+03 eff:32.0% logz-ratio=251.05+/-0.08 dlogz:3.173>3]
# 824it [00:47,  8.77it/s, bound:0 nc:  9 ncall:2.6e+03 eff:31.9% logz-ratio=251.06+/-0.08 dlogz:3.158>3]
# 826it [00:47,  9.28it/s, bound:0 nc:  4 ncall:2.6e+03 eff:31.8% logz-ratio=251.08+/-0.08 dlogz:3.143>3]
# 828it [00:47,  7.86it/s, bound:0 nc: 11 ncall:2.6e+03 eff:31.6% logz-ratio=251.09+/-0.08 dlogz:3.129>3]
# 830it [00:47,  8.03it/s, bound:0 nc: 11 ncall:2.6e+03 eff:31.5% logz-ratio=251.10+/-0.08 dlogz:3.114>3]
# 831it [00:48,  8.25it/s, bound:0 nc:  5 ncall:2.6e+03 eff:31.5% logz-ratio=251.10+/-0.08 dlogz:3.107>3]
# 833it [00:48,  9.19it/s, bound:0 nc:  5 ncall:2.6e+03 eff:31.5% logz-ratio=251.11+/-0.08 dlogz:3.093>3]
# 834it [00:48,  8.92it/s, bound:0 nc:  7 ncall:2.7e+03 eff:31.4% logz-ratio=251.12+/-0.08 dlogz:3.086>3]
# 835it [00:48,  9.00it/s, bound:0 nc:  6 ncall:2.7e+03 eff:31.4% logz-ratio=251.13+/-0.08 dlogz:3.079>3]
# 838it [00:48, 12.89it/s, bound:0 nc:  3 ncall:2.7e+03 eff:31.4% logz-ratio=251.14+/-0.08 dlogz:3.058>3]
# 841it [00:48, 16.39it/s, bound:0 nc:  2 ncall:2.7e+03 eff:31.5% logz-ratio=251.16+/-0.08 dlogz:3.037>3]
# 843it [00:48, 12.71it/s, bound:0 nc:  7 ncall:2.7e+03 eff:31.3% logz-ratio=251.17+/-0.08 dlogz:3.023>3]
# 845it [00:49, 11.72it/s, bound:0 nc:  6 ncall:2.7e+03 eff:31.3% logz-ratio=251.18+/-0.08 dlogz:3.009>3]
# 15:37 bilby INFO    : Written checkpoint file short/GW150914_resume.pickle
# 15:37 bilby INFO    : Writing 227 current samples to short/GW150914_samples.dat
# /usr/local/lib/python3.7/dist-packages/dynesty/utils.py:143: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   idx = np.zeros(nsamples, dtype=np.int)
# /usr/local/lib/python3.7/dist-packages/dynesty/utils.py:143: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   idx = np.zeros(nsamples, dtype=np.int)
# 846it [00:51, 16.29it/s, bound:0 nc:  1 ncall:2.7e+03 eff:49.8% logz-ratio=253.31+/-0.07 dlogz:0.004>3]
# /usr/local/lib/python3.7/dist-packages/dynesty/utils.py:143: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   idx = np.zeros(nsamples, dtype=np.int)
# 15:37 bilby INFO    : Sampling time: 0:00:38.544594
# /usr/local/lib/python3.7/dist-packages/bilby/core/result.py:1294: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   if "npool" in inspect.getargspec(conversion_function).args:
# 15:37 bilby INFO    : Reconstructing marginalised parameters.
#   0%|          | 0/1346 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/bilby/gw/source.py:384: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   h_plus = np.zeros_like(frequency_array, dtype=np.complex)
# /usr/local/lib/python3.7/dist-packages/bilby/gw/source.py:385: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   h_cross = np.zeros_like(frequency_array, dtype=np.complex)
# /usr/local/lib/python3.7/dist-packages/bilby/gw/likelihood.py:421: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   d_inner_h = np.zeros(len(times), dtype=np.complex)
# /usr/local/lib/python3.7/dist-packages/bilby/gw/likelihood.py:423: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   signal_long = np.zeros(n_time_steps, dtype=np.complex)
# /usr/local/lib/python3.7/dist-packages/bilby/gw/likelihood.py:424: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data
#  94%|█████████▍| 1267/1346 [00:22<00:01, 57.73it/s]
#  95%|█████████▍| 1273/1346 [00:22<00:01, 58.25it/s]
#  95%|█████████▌| 1279/1346 [00:22<00:01, 58.35it/s]
#  96%|█████████▌| 1286/1346 [00:22<00:01, 59.78it/s]
#  96%|█████████▌| 1293/1346 [00:22<00:00, 60.62it/s]
#  97%|█████████▋| 1300/1346 [00:22<00:00, 60.21it/s]
#  97%|█████████▋| 1307/1346 [00:23<00:00, 59.80it/s]
#  98%|█████████▊| 1313/1346 [00:23<00:00, 58.60it/s]
#  98%|█████████▊| 1319/1346 [00:23<00:00, 58.03it/s]
#  99%|█████████▊| 1326/1346 [00:23<00:00, 59.13it/s]
#  99%|█████████▉| 1333/1346 [00:23<00:00, 59.88it/s]
#  99%|█████████▉| 1339/1346 [00:23<00:00, 59.49it/s]
# 100%|██████████| 1346/1346 [00:23<00:00, 56.72it/s]
# 15:42 bilby INFO    : Summary of results:
# nsamples: 1346
# ln_noise_evidence: -2980052.045
# ln_evidence: -2979798.730 +/-  0.068
# ln_bayes_factor: 253.314 +/-  0.068

# %% [markdown]
# ### Looking at the outputs

# %% [markdown]
# The `run_sampler` returned `result_short` - this is a Bilby result object. The posterior samples are stored in a [pandas data frame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) (think of this like a spreadsheet); let's take a look at it

# %%
result_short.posterior
# Out:
#       chirp_mass  mass_ratio  time_jitter     phase  geocent_time  a_1  a_2  \
# 0      30.593809    0.760404    -0.000243  6.024469   1204.689599  0.0  0.0
# 1      32.274491    0.750494     0.000131  5.560018   1204.688944  0.0  0.0
# 2      31.890839    0.742878    -0.000048  2.502707   1204.689174  0.0  0.0
# 3      31.089906    0.739721    -0.000031  5.724329   1204.689334  0.0  0.0
# 4      31.871603    0.749238    -0.000063  2.427198   1204.689011  0.0  0.0
# ...          ...         ...          ...       ...           ...  ...  ...
# 1341   31.651168    0.987013    -0.000221  2.913323   1204.689297  0.0  0.0
# 1342   31.651168    0.987013    -0.000221  2.973278   1204.689567  0.0  0.0
# 1343   31.651168    0.987013    -0.000221  6.037271   1204.689486  0.0  0.0
# 1344   31.651168    0.987013    -0.000221  6.131040   1204.689403  0.0  0.0
# 1345   31.651168    0.987013    -0.000221  2.944738   1204.689276  0.0  0.0
#
#       tilt_1  tilt_2  phi_12  ...  redshift  comoving_distance  mass_1_source  \
# 0        0.0     0.0     0.0  ...  0.087423         378.938181      37.130521
# 1        0.0     0.0     0.0  ...  0.087423         378.938181      39.435265
# 2        0.0     0.0     0.0  ...  0.087423         378.938181      39.171521
# 3        0.0     0.0     0.0  ...  0.087423         378.938181      38.271552
# 4        0.0     0.0     0.0  ...  0.087423         378.938181      38.976559
# ...      ...     ...     ...  ...       ...                ...            ...
# 1341     0.0     0.0     0.0  ...  0.087423         378.938181      33.654090
# 1342     0.0     0.0     0.0  ...  0.087423         378.938181      33.654090
# 1343     0.0     0.0     0.0  ...  0.087423         378.938181      33.654090
# 1344     0.0     0.0     0.0  ...  0.087423         378.938181      33.654090
# 1345     0.0     0.0     0.0  ...  0.087423         378.938181      33.654090
#
#       mass_2_source  chirp_mass_source  total_mass_source  \
# 0         28.234187          28.134236          65.364708
# 1         29.595931          29.679801          69.031196
# 2         29.099660          29.326992          68.271181
# 3         28.310279          28.590450          66.581832
# 4         29.202706          29.309303          68.179265
# ...             ...                ...                ...
# 1341      33.217008          29.106590          66.871098
# 1342      33.217008          29.106590          66.871098
# 1343      33.217008          29.106590          66.871098
# 1344      33.217008          29.106590          66.871098
# 1345      33.217008          29.106590          66.871098
#
#       H1_matched_filter_snr  H1_optimal_snr  L1_matched_filter_snr  \
# 0       28.017625+3.675067j       10.154600     7.658408-7.266579j
# 1       27.510733+1.893133j       10.605950     7.201036-6.896119j
# 2       27.664907+3.683274j       10.493898     7.436395-6.731069j
# 3       27.118141+7.188616j       10.271799     8.689722-5.975913j
# 4       27.161492+4.943314j       10.495356     8.216993-6.261701j
# ...                     ...             ...                    ...
# 1341    27.431794+4.204149j       10.544189     8.328175-6.886754j
# 1342    27.166185+7.707102j       10.544189     8.543376-6.073546j
# 1343    26.331898+9.854726j       10.544189     9.189989-5.262145j
# 1344    27.841520+2.679557j       10.544189     7.701633-7.414317j
# 1345    27.636941+1.963547j       10.544189     7.784001-7.525720j
#
#      L1_optimal_snr
# 0          7.093831
# 1          7.391058
# 2          7.316038
# 3          7.168860
# 4          7.317720
# ...             ...
# 1341       7.362586
# 1342       7.362586
# 1343       7.362586
# 1344       7.362586
# 1345       7.362586
#
# [1346 rows x 50 columns]

# %% [markdown]
# We can pull out specific parameters that we are interested in

# %%
result_short.posterior["chirp_mass"]
# Out:
# 0       30.593809
# 1       32.274491
# 2       31.890839
# 3       31.089906
# 4       31.871603
#           ...
# 1341    31.651168
# 1342    31.651168
# 1343    31.651168
# 1344    31.651168
# 1345    31.651168
# Name: chirp_mass, Length: 1346, dtype: float64

# %% [markdown]
# This returned another `pandas` object. If you just want to get the numbers as a numpy array run

# %%
Mc = result_short.posterior["chirp_mass"].values

# %% [markdown]
# We can then get some useful quantities such as the 90\% credible interval

# %%
lower_bound = np.quantile(Mc, 0.05)
upper_bound = np.quantile(Mc, 0.95)
median = np.quantile(Mc, 0.5)
print("Mc = {} with a 90% C.I = {} -> {}".format(median, lower_bound, upper_bound))
# Out:
# Mc = 31.63065796480537 with a 90% C.I = 30.991677573398732 -> 32.343736812549274

# %% [markdown]
# We can then plot the chirp mass in a histogram adding a region to indicate the 90\% C.I.

# %%
fig, ax = plt.subplots()
ax.hist(result_short.posterior["chirp_mass"], bins=20)
ax.axvspan(lower_bound, upper_bound, color='C1', alpha=0.4)
ax.axvline(median, color='C1')
ax.set_xlabel("chirp mass")
plt.show()

# %% [markdown]
# The result object also has in-built methods to make nice plots such as corner plots. You can add the priors if you are only plotting parameters which you sampled in, e.g.

# %%
result_short.plot_corner(parameters=["chirp_mass", "mass_ratio", "geocent_time", "phase"], prior=True)

# %% [markdown]
# You can also plot lines indicating specific points. Here, we add the values recorded on [GWOSC](https://www.gw-openscience.org/events/GW150914/). Notably, these fall outside the bulk of the posterior uncertainty here. This is because we limited our prior - if instead we ran the full analysis these agree nicely.

# %%
parameters = dict(mass_1=36.2, mass_2=29.1)
result_short.plot_corner(parameters)

# %% [markdown]
# Earlier we discussed the "correlation" - in this plot we start to see the correlation between $m_1$ and $m_2$.

# %% [markdown]
# ### Meta data
# The result object also stores meta data, like the priors

# %%
result_short.priors
# Out:
# {'a_1': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'a_2': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'chirp_mass': Uniform(minimum=30.0, maximum=32.5, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None),
#  'dec': DeltaFunction(peak=-1.2232, name=None, latex_label=None, unit=None),
#  'geocent_time': Uniform(minimum=1203.7, maximum=1207.8999999999999, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None),
#  'luminosity_distance': DeltaFunction(peak=412.066, name=None, latex_label=None, unit=None),
#  'mass_ratio': Uniform(minimum=0.5, maximum=1, name='mass_ratio', latex_label='$q$', unit=None, boundary=None),
#  'phase': Uniform(minimum=0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary=None),
#  'phi_12': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'phi_jl': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'psi': DeltaFunction(peak=0.532268, name=None, latex_label=None, unit=None),
#  'ra': DeltaFunction(peak=2.19432, name=None, latex_label=None, unit=None),
#  'theta_jn': DeltaFunction(peak=1.89694, name=None, latex_label=None, unit=None),
#  'tilt_1': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'tilt_2': DeltaFunction(peak=0.0, name=None, latex_label=None, unit=None),
#  'time_jitter': Uniform(minimum=-0.000244140625, maximum=0.000244140625, name=None, latex_label=None, unit=None, boundary='periodic')}

# %% [markdown]
# and details of the analysis itself:

# %%
result_short.sampler_kwargs["nlive"]
# Out:
# 500

# %% [markdown]
# Finally, we can also get out the Bayes factor for the signal vs. Gaussian noise. This quantifies the probability that the analyzed segment contains a binary black hole signal compared to just containing noise.

# %%
print("ln Bayes factor = {} +/- {}".format(
    result_short.log_bayes_factor, result_short.log_evidence_err))
# Out:
# ln Bayes factor = 253.3144744350432 +/- 0.06776201959385017

# %% [markdown]
# ## Challenge questions
# First, let's take a closer look at the result obtained with the run above. What are the means of the chirp mass and mass ratio distributions? What are the medians of the distributions for the components masses? You can use `np.mean` and `np.median` to calculate these.
#
# Now let's expand on this example a bit. Rerun the analysis above but change the prior on the distance from a delta function to `bilby.core.prior.PowerLaw(alpha=2., minimum=50., maximum=800., name='luminosity_distance')`. You should also replace `sample='unif'` with `sample="rwalk", nact=1, walks=1` in your call to `bilby.run_sampler` above. This will take a bit longer than the original run, around ~20 minutes. You also need to change the `label` in the call to `run_sampler` to avoid over-writing your results.
#
# What is the median reported value of the distance posterior? What is the new log Bayes factor for signal vs. Gaussian noise? Don't be alarmed if your results do not match the official LVC results, as these are not rigorous settings.

# %% [markdown]
# # Means and medians of the chirp mass and mass ratio

# %%
m_chirp = result_short.posterior["chirp_mass"]
q = result_short.posterior["mass_ratio"]
print("chirp mass mean",np.mean(m_chirp))
print("mass ratio mean",np.mean(q))
print("chirp mass median",np.median(m_chirp))
print("mass ratio median",np.median(q))
# Out:
# chirp mass mean 31.643704061411274
# mass ratio mean 0.9321476613622544
# chirp mass median 31.63065796480537
# mass ratio median 0.9442507516295188
